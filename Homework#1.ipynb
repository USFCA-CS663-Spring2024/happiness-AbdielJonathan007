# %%
import pandas as pd
# Out:
# /var/folders/18/nl99l9ns60b8w005rkqx765m0000gn/T/ipykernel_20906/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import seaborn as sns

# %%
File = 'DataForTable2.1WHR2023.xls'
df = pd.read_excel(File, engine = 'xlrd')

# %%
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479226            9.389766        0.810679
# std       4.718736     1.125529            1.153387        0.120952
# min    2005.000000     1.281271            5.526723        0.228217
# 25%    2010.000000     4.646750            8.499764        0.746609
# 50%    2014.000000     5.432437            9.498955        0.835535
# 75%    2018.000000     6.309460           10.373216        0.904792
# max    2022.000000     8.018934           11.663788        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294583                      0.747858
# std                            6.901104                      0.140150
# min                            6.720000                      0.257534
# ...

# %%
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018     3.616480            7.783066        0.775388
# 2195     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2196     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2197     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2199 non-null   object
#  1   year                              2199 non-null   int64
#  2   Life Ladder                       2199 non-null   float64
#  3   Log GDP per capita                2179 non-null   float64
#  4   Social support                    2186 non-null   float64
#  5   Healthy life expectancy at birth  2145 non-null   float64
#  6   Freedom to make life choices      2166 non-null   float64
#  7   Generosity                        2126 non-null   float64
#  8   Perceptions of corruption         2083 non-null   float64
#  9   Positive affect                   2175 non-null   float64
#  10  Negative affect                   2183 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df.isna().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   20
# Social support                       13
# Healthy life expectancy at birth     54
# Freedom to make life choices         33
# Generosity                           73
# Perceptions of corruption           116
# Positive affect                      24
# Negative affect                      16
# dtype: int64

# %% [markdown]
# #Data Quality Report
#
# How large is the dataset?
# *Dataset is composed of 11 columns and 2199 rows.
# *There is some that missing specially for **Perceptions of Corruption**
# * Total missing data 334

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(ncols=5, figsize= (22,6))
sns.histplot(df['Positive affect'], ax = axs[0])
sns.histplot(df['Negative affect'], ax = axs[1])
sns.histplot(df['Generosity'], ax = axs[2])
sns.histplot(df['Perceptions of corruption'], ax = axs[3])
sns.histplot(df['Healthy life expectancy at birth'], ax = axs[4])

plt.show()

# %%
df2 = df.drop(['Country name'], axis = 1)
sns.heatmap(df2.corr(), annot =True)
plt.show()

# %%
sns.scatterplot(data = df, x =df['Life Ladder'], y = df['Healthy life expectancy at birth'])
# Out:
# <Axes: xlabel='Life Ladder', ylabel='Healthy life expectancy at birth'>

# %%
sns.scatterplot(data = df, x='Country name', y='Life Ladder')
# Out:
# <Axes: xlabel='Country name', ylabel='Life Ladder'>

# %%
df.loc[df['Life Ladder'].idxmax()]
# Out:
# Country name                          Denmark
# year                                     2005
# Life Ladder                          8.018934
# Log GDP per capita                  10.849012
# Social support                       0.972372
# Healthy life expectancy at birth    68.300003
# Freedom to make life choices         0.971135
# Generosity                                NaN
# Perceptions of corruption            0.236522
# Positive affect                      0.776689
# Negative affect                      0.153672
# Name: 505, dtype: object

# %%
sns.barplot(x='Country name', y='Life Ladder', data=df).idxmax()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sns.barplot(x='Country name', y='Life Ladder', data=df).idxmax()
#
# AttributeError: 'Axes' object has no attribute 'idxmax'

# %%
df_2022 = df[df['year'] == 2022]

# %%
df_2022
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 13    Afghanistan  2022     1.281271                 NaN        0.228217
# 28        Albania  2022     5.212213            9.626483        0.724090
# 59      Argentina  2022     6.260993           10.011405        0.893330
# 75        Armenia  2022     5.381943            9.667766        0.811169
# 91      Australia  2022     7.034696           10.853529        0.941673
# ...           ...   ...          ...                 ...             ...
# 2104      Uruguay  2022     6.670853           10.084121        0.904825
# 2120   Uzbekistan  2022     6.016239            8.989866        0.878923
# 2137    Venezuela  2022     5.948992                 NaN        0.899366
# 2154      Vietnam  2022     6.266509            9.332854        0.878744
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df_2022.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
df_2022['Life Ladder'].isnull().sum()
# Out:
# 0

# %%
happiest_country_2022 = df_2022.loc[df_2022['Life Ladder'].idxmax()]

# %%
happiest_country_2022 = df_2022.loc[df_2022['Life Ladder'].idxmax(), 'Country name']

print(f"The happiest country in 2022 was {happiest_country_2022}.")
# Out:
# The happiest country in 2022 was Finland.

# %%
happiest_country_2022 = df_2022.loc[df_2022['Life Ladder'].idxmin(), 'Country name']

print(f"The least Happiest country in 2022 was {happiest_country_2022}.")
# Out:
# The least Happiest country in 2022 was Afghanistan.

# %%
df_2013 = df[df['year'] == 2013]

# %%
df_2013['Life Ladder'].isnull().sum()
# Out:
# 0

# %%
happiest_country_2013 = df_2013.loc[df_2013['Life Ladder'].idxmax()]

# %%
happiest_country_2013 = df_2013.loc[df_2013['Life Ladder'].idxmax(), 'Country name']

print(f"The happiest country in 2013 was {happiest_country_2013}.")
# Out:
# The happiest country in 2013 was Canada.

# %%
happiest_country_2013 = df_2013.loc[df_2013['Life Ladder'].idxmin(), 'Country name']

print(f"The least Happiest country in 2013 was {happiest_country_2013}.")
# Out:
# The least Happiest country in 2013 was Syria.

# %% [markdown]
# ### The least Happiest country in 2013 was Syria.
# ### The happiest country in 2013 was Canada.

# %% [markdown]
# ### The least Happiest country in 2022 was Syria.
# ### The happiest country in 2022 was Canada.

# %% [markdown]
# ## Question 3
